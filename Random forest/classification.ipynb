# %% [markdown]
# # New York State Hospital Inpatient Discharge
# Source: https://www.kaggle.com/datasets/thedevastator/2010-new-york-state-hospital-inpatient-discharge

# %% [markdown]
# ## Data Loading

# %%
import pandas as pd

# %%
df = pd.read_csv("Project_2_Data/hospital-inpatient-discharges-sparcs-de-identified-2010-1.csv", low_memory=False)
df.head()
# Out:
#    index Health Service Area Hospital County  Operating Certificate Number  \
# 0      0      Capital/Adiron          Albany                      101000.0
# 1      1      Capital/Adiron          Albany                      101000.0
# 2      2      Capital/Adiron          Albany                      101000.0
# 3      3      Capital/Adiron          Albany                      101000.0
# 4      4      Capital/Adiron          Albany                      101000.0
#
#    Facility ID                   Facility Name    Age Group  \
# 0          1.0  Albany Medical Center Hospital     18 to 29
# 1          1.0  Albany Medical Center Hospital     50 to 69
# 2          1.0  Albany Medical Center Hospital  70 or Older
# 3          1.0  Albany Medical Center Hospital  70 or Older
# 4          1.0  Albany Medical Center Hospital  70 or Older
#
#   Zip Code - 3 digits Gender   Race  ... Source of Payment 2  \
# 0                 NaN      F  White  ...            Self-Pay
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622133 entries, 0 to 2622132
# Data columns (total 38 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   index                                int64
#  1   Health Service Area                  object
#  2   Hospital County                      object
#  3   Operating Certificate Number         float64
#  4   Facility ID                          float64
#  5   Facility Name                        object
#  6   Age Group                            object
#  7   Zip Code - 3 digits                  object
#  8   Gender                               object
#  9   Race                                 object
#  10  Ethnicity                            object
#  11  Length of Stay                       object
#  12  Type of Admission                    object
#  13  Patient Disposition                  object
#  14  Discharge Year                       int64
# ...

# %%
df.describe()
# Out:
#               index  Operating Certificate Number   Facility ID  \
# count  2.622133e+06                  2.617246e+06  2.617246e+06
# mean   1.311066e+06                  5.019051e+06  1.036953e+03
# std    7.569447e+05                  2.249577e+06  6.448892e+02
# min    0.000000e+00                  1.010000e+05  1.000000e+00
# 25%    6.555330e+05                  2.951001e+06  5.410000e+02
# 50%    1.311066e+06                  5.907002e+06  1.117000e+03
# 75%    1.966599e+06                  7.002002e+06  1.450000e+03
# max    2.622132e+06                  7.004010e+06  9.059000e+03
#
#        Discharge Year  CCS Diagnosis Code  CCS Procedure Code  APR DRG Code  \
# count       2622133.0        2.619860e+06        2.619860e+06  2.622133e+06
# mean           2010.0        1.919431e+02        1.121324e+02  4.069629e+02
# std               0.0        1.565932e+02        8.761224e+01  2.404910e+02
# min            2010.0        1.000000e+00        0.000000e+00  1.000000e+00
# ...

# %%
df["Facility ID"].unique()
# Out:
# array([1.000e+00, 2.000e+00, 4.000e+00, 5.000e+00, 3.700e+01, 3.900e+01,
#        4.200e+01, 4.300e+01, 5.800e+01, 6.600e+01, 8.500e+01, 9.800e+01,
#        1.030e+02, 1.110e+02, 1.140e+02, 1.160e+02, 1.180e+02, 1.280e+02,
#        1.350e+02, 1.460e+02, 1.580e+02, 1.650e+02, 1.700e+02, 1.740e+02,
#        1.790e+02, 1.800e+02, 1.810e+02, 1.920e+02, 2.070e+02, 2.080e+02,
#        2.100e+02, 2.110e+02, 2.130e+02, 2.150e+02, 2.160e+02, 2.180e+02,
#        2.450e+02, 2.670e+02, 2.800e+02, 2.920e+02, 3.030e+02, 3.090e+02,
#        3.240e+02, 3.250e+02, 3.300e+02, 3.390e+02, 3.400e+02, 3.620e+02,
#        3.670e+02, 3.770e+02, 3.790e+02, 3.830e+02, 3.930e+02, 3.970e+02,
#        4.010e+02, 4.090e+02, 4.110e+02, 4.120e+02, 4.130e+02, 4.140e+02,
#        4.610e+02, 4.710e+02, 4.820e+02, 4.840e+02, 4.900e+02, 4.950e+02,
#        5.110e+02, 5.130e+02, 5.180e+02, 5.270e+02, 5.280e+02, 5.410e+02,
#        5.500e+02, 5.510e+02, 5.520e+02, 5.630e+02, 5.650e+02, 5.740e+02,
# ...

# %% [markdown]
# ## Description

# %% [markdown]
# ### Shape

# %%
df.shape
# Out:
# (2622133, 38)

# %% [markdown]
# ### Columns

# %%
df.columns.tolist()
# Out:
# ['index',
#  'Health Service Area',
#  'Hospital County',
#  'Operating Certificate Number',
#  'Facility ID',
#  'Facility Name',
#  'Age Group',
#  'Zip Code - 3 digits',
#  'Gender',
#  'Race',
#  'Ethnicity',
#  'Length of Stay',
#  'Type of Admission',
#  'Patient Disposition',
#  'Discharge Year',
#  'CCS Diagnosis Code',
#  'CCS Diagnosis Description',
#  'CCS Procedure Code',
#  'CCS Procedure Description',
#  'APR DRG Code',
#  'APR DRG Description',
#  'APR MDC Code',
#  'APR MDC Description',
#  'APR Severity of Illness Code',
#  'APR Severity of Illness Description',
#  'APR Risk of Mortality',
#  'APR Medical Surgical Description',
#  'Source of Payment 1',
#  'Source of Payment 2',
#  'Source of Payment 3',
#  'Attending Provider License Number',
#  'Operating Provider License Number',
#  'Other Provider License Number',
#  'Birth Weight',
#  'Abortion Edit Indicator',
#  'Emergency Department Indicator',
#  'Total Charges',
#  'Total Costs']

# %% [markdown]
# #### Description of Columns
# - **Health Service Area** - Geographic region of the hospital. (String)
# - **Hospital County** - County in which the hospital is located. (String)
# - **Operating Certificate Number** - Unique identifier for hospitals. (Integer)
# - **Facility Name** -	Name of the hospital. (String)
# - **Age Group** - Age group of the patient. (String)
# - **Zip Code 3 digits** - First three digits of the patient's zip code. (Integer)
# - **Gender** - Gender of the patient. (String)
# - **Race** - Race of the patient. (String)
# - **Ethnicity** - Ethnicity of the patient. (String)
# - **Length of Stay** - Length of stay for the patient. (Integer)
# - **Type of Admission** -	Type of admission for the patient. (String)
# - **Patient Disposition** - Disposition of the patient. (String)
# - **Discharge Year** - Year of the patient's discharge. (Integer)
# - **CCS Diagnosis Code** - Clinical Classification Software (CCS) diagnosis code for the patient. (Integer)
# - **CCS Diagnosis Description** - CCS Diagnosis Description. (String)
# - **CCS Procedure Code** - CCS procedure code for the patient. (Integer)
# - **CCS Procedure Description** -	CCS Procedure Description. (String)
# - **APR DRG Code** - All Patient Refined Diagnosis Related Group APR DRG Code. (Integer)
# - **APR DRG Description** - APR DRG Description. (String)
# - **APR MDC Code** - All Patient Refined Major Diagnostic Category APR MDC Code. (Integer)
# - **APR MDC Description** - APR MDC Description. (String)
# - **APR Severity of Illness Code** - APR Severity of Illness Code. (Integer)
# - **APR Severity of Illness Description** - APR Severity of Illness Description. (String)
# - **APR Risk of Mortality** - APR Risk of Mortality. (Integer)
# - **APR Medical Surgical Description** - APR Medical Surgical Description. (String)
# - **Source of Payment 1** - Source of Payment 1. (String)
# - **Source of Payment 2**	- Source of Payment 2
# - **Source of Payment 3**	- Source of Payment 3

# %% [markdown]
# ### Attribute Types

# %%
df.dtypes
# Out:
# index                                    int64
# Health Service Area                     object
# Hospital County                         object
# Operating Certificate Number           float64
# Facility ID                            float64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# CCS Diagnosis Code                     float64
# CCS Diagnosis Description               object
# CCS Procedure Code                     float64
# CCS Procedure Description               object
# APR DRG Code                             int64
# ...

# %% [markdown]
# ### `null` Values

# %%
df.isnull().sum()
# Out:
# index                                        0
# Health Service Area                       4887
# Hospital County                           4887
# Operating Certificate Number              4887
# Facility ID                               4887
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                       3201
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                        103
# Discharge Year                               0
# CCS Diagnosis Code                        2273
# CCS Diagnosis Description                 2273
# CCS Procedure Code                        2273
# CCS Procedure Description                 2273
# APR DRG Code                                 0
# ...

# %% [markdown]
# ### Attribute Description (Summary)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622133 entries, 0 to 2622132
# Data columns (total 38 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   index                                int64
#  1   Health Service Area                  object
#  2   Hospital County                      object
#  3   Operating Certificate Number         float64
#  4   Facility ID                          float64
#  5   Facility Name                        object
#  6   Age Group                            object
#  7   Zip Code - 3 digits                  object
#  8   Gender                               object
#  9   Race                                 object
#  10  Ethnicity                            object
#  11  Length of Stay                       object
#  12  Type of Admission                    object
#  13  Patient Disposition                  object
#  14  Discharge Year                       int64
# ...

# %% [markdown]
# ## Preprocessing

# %%
df.isnull().sum()
# Out:
# index                                        0
# Health Service Area                       4887
# Hospital County                           4887
# Operating Certificate Number              4887
# Facility ID                               4887
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                       3201
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                        103
# Discharge Year                               0
# CCS Diagnosis Code                        2273
# CCS Diagnosis Description                 2273
# CCS Procedure Code                        2273
# CCS Procedure Description                 2273
# APR DRG Code                                 0
# ...

# %%
print("Total Rows :",len(df.index))
# Out:
# Total Rows : 2622133

# %% [markdown]
# **Deleting the columns** that have large portion of values `null`.

# %%
df = df.drop(['Source of Payment 3', 'Other Provider License Number'], axis = 1)

# %%
df.isnull().sum()
# Out:
# index                                       0
# Health Service Area                      4887
# Hospital County                          4887
# Operating Certificate Number             4887
# Facility ID                              4887
# Facility Name                               0
# Age Group                                   0
# Zip Code - 3 digits                      3201
# Gender                                      0
# Race                                        0
# Ethnicity                                   0
# Length of Stay                              0
# Type of Admission                           0
# Patient Disposition                       103
# Discharge Year                              0
# CCS Diagnosis Code                       2273
# CCS Diagnosis Description                2273
# CCS Procedure Code                       2273
# CCS Procedure Description                2273
# APR DRG Code                                0
# ...

# %% [markdown]
# Removing rest of the `null` values containing rows.

# %%
modified_df = df.dropna(subset=['Health Service Area', 'Hospital County', 'Operating Certificate Number', 'Facility ID', 'Zip Code - 3 digits', 'Patient Disposition', 'CCS Diagnosis Code', 'CCS Diagnosis Description', 'CCS Procedure Code', 'CCS Procedure Description', 'APR Severity of Illness Description', 'APR Risk of Mortality', 'Attending Provider License Number'])

# %%
modified_df.isnull().sum()
# Out:
# index                                       0
# Health Service Area                         0
# Hospital County                             0
# Operating Certificate Number                0
# Facility ID                                 0
# Facility Name                               0
# Age Group                                   0
# Zip Code - 3 digits                         0
# Gender                                      0
# Race                                        0
# Ethnicity                                   0
# Length of Stay                              0
# Type of Admission                           0
# Patient Disposition                         0
# Discharge Year                              0
# CCS Diagnosis Code                          0
# CCS Diagnosis Description                   0
# CCS Procedure Code                          0
# CCS Procedure Description                   0
# APR DRG Code                                0
# ...

# %% [markdown]
# **Placing mode on missing value** on the ramaining `null` rows.

# %%
variables =['Source of Payment 2','Operating Provider License Number']
modified_df[variables] = modified_df[variables].fillna(modified_df[variables].mode().iloc[0])
# Out:
# C:\Users\borad\AppData\Local\Temp\ipykernel_21708\1865121224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modified_df[variables] = modified_df[variables].fillna(modified_df[variables].mode().iloc[0])

# %%
modified_df.isnull().sum()
# Out:
# index                                  0
# Health Service Area                    0
# Hospital County                        0
# Operating Certificate Number           0
# Facility ID                            0
# Facility Name                          0
# Age Group                              0
# Zip Code - 3 digits                    0
# Gender                                 0
# Race                                   0
# Ethnicity                              0
# Length of Stay                         0
# Type of Admission                      0
# Patient Disposition                    0
# Discharge Year                         0
# CCS Diagnosis Code                     0
# CCS Diagnosis Description              0
# CCS Procedure Code                     0
# CCS Procedure Description              0
# APR DRG Code                           0
# APR DRG Description                    0
# APR MDC Code                           0
# APR MDC Description                    0
# ...

# %% [markdown]
# ### Label Encoding

# %%
modified_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2611433 entries, 5 to 2617245
# Data columns (total 36 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   index                                int64
#  1   Health Service Area                  object
#  2   Hospital County                      object
#  3   Operating Certificate Number         float64
#  4   Facility ID                          float64
#  5   Facility Name                        object
#  6   Age Group                            object
#  7   Zip Code - 3 digits                  object
#  8   Gender                               object
#  9   Race                                 object
#  10  Ethnicity                            object
#  11  Length of Stay                       object
#  12  Type of Admission                    object
#  13  Patient Disposition                  object
#  14  Discharge Year                       int64
# ...

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

columns = ['Health Service Area', 'Hospital County', 'Facility Name', 'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race', 'Ethnicity', 'Length of Stay', 'Type of Admission', 'Patient Disposition', 'CCS Diagnosis Description', 'CCS Procedure Description', 'APR DRG Description', 'APR MDC Description', 'APR Severity of Illness Description', 'APR Risk of Mortality', 'APR Medical Surgical Description', 'Source of Payment 1', 'Source of Payment 2', 'Abortion Edit Indicator', 'Emergency Department Indicator']

for column in columns:
    modified_df[column + ' Encoded'] = le.fit_transform(modified_df[column])
# Out:
# C:\Users\borad\AppData\Local\Temp\ipykernel_21708\3175350202.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modified_df[column + ' Encoded'] = le.fit_transform(modified_df[column])
# C:\Users\borad\AppData\Local\Temp\ipykernel_21708\3175350202.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modified_df[column + ' Encoded'] = le.fit_transform(modified_df[column])
# C:\Users\borad\AppData\Local\Temp\ipykernel_21708\3175350202.py:8: SettingWithCopyWarning:
# ...

# %%
modified_df
# Out:
#            index Health Service Area Hospital County  \
# 5              5      Capital/Adiron          Albany
# 6              6      Capital/Adiron          Albany
# 7              7      Capital/Adiron          Albany
# 8              8      Capital/Adiron          Albany
# 9              9      Capital/Adiron          Albany
# ...          ...                 ...             ...
# 2617241  2617241          Central NY        Onondaga
# 2617242  2617242          Central NY        Onondaga
# 2617243  2617243          Central NY        Onondaga
# 2617244  2617244          Central NY        Onondaga
# 2617245  2617245          Central NY        Onondaga
#
#          Operating Certificate Number  Facility ID  \
# 5                            101000.0          1.0
# 6                            101000.0          1.0
# 7                            101000.0          1.0
# 8                            101000.0          1.0
# 9                            101000.0          1.0
# ...

# %%
modified_df.columns.tolist()
# Out:
# ['index',
#  'Health Service Area',
#  'Hospital County',
#  'Operating Certificate Number',
#  'Facility ID',
#  'Facility Name',
#  'Age Group',
#  'Zip Code - 3 digits',
#  'Gender',
#  'Race',
#  'Ethnicity',
#  'Length of Stay',
#  'Type of Admission',
#  'Patient Disposition',
#  'Discharge Year',
#  'CCS Diagnosis Code',
#  'CCS Diagnosis Description',
#  'CCS Procedure Code',
#  'CCS Procedure Description',
#  'APR DRG Code',
#  'APR DRG Description',
#  'APR MDC Code',
#  'APR MDC Description',
#  'APR Severity of Illness Code',
#  'APR Severity of Illness Description',
#  'APR Risk of Mortality',
#  'APR Medical Surgical Description',
#  'Source of Payment 1',
#  'Source of Payment 2',
#  'Attending Provider License Number',
#  'Operating Provider License Number',
#  'Birth Weight',
#  'Abortion Edit Indicator',
#  'Emergency Department Indicator',
#  'Total Charges',
#  'Total Costs',
#  'Health Service Area Encoded',
#  'Hospital County Encoded',
# ...

# %% [markdown]
# **Correlation Map**

# %%
import seaborn as sns
sns.heatmap(data=modified_df[[
 'Operating Certificate Number',
 'Facility ID',
 'Discharge Year',
 'CCS Diagnosis Code',
 'CCS Procedure Code',
 'APR DRG Code',
 'APR MDC Code',
 'APR Severity of Illness Code',
 'Attending Provider License Number',
 'Operating Provider License Number',
 'Birth Weight',
 'Total Charges',
 'Total Costs',
 'Health Service Area Encoded',
 'Hospital County Encoded',
 'Facility Name Encoded',
 'Age Group Encoded',
 'Zip Code - 3 digits Encoded',
 'Gender Encoded',
 'Race Encoded',
 'Ethnicity Encoded',
 'Length of Stay Encoded',
 'Type of Admission Encoded',
 'Patient Disposition Encoded',
 'CCS Diagnosis Description Encoded',
 'CCS Procedure Description Encoded',
 'APR DRG Description Encoded',
 'APR MDC Description Encoded',
 'APR Severity of Illness Description Encoded',
 'APR Risk of Mortality Encoded',
 'APR Medical Surgical Description Encoded',
 'Source of Payment 1 Encoded',
 'Source of Payment 2 Encoded',
 'Abortion Edit Indicator Encoded',
 'Emergency Department Indicator Encoded']].corr(), lw = 1)
# Out:
# <Axes: >

# %% [markdown]
# ## Classification

# %%
X = [
 'Operating Certificate Number',
 'Facility ID',
 'Discharge Year',
 'CCS Diagnosis Code',
 'CCS Procedure Code',
 'APR DRG Code',
 'APR MDC Code',
 'APR Severity of Illness Code',
 'Attending Provider License Number',
 'Operating Provider License Number',
 'Birth Weight',
 'Total Charges',
 'Total Costs',
 'Health Service Area Encoded',
 'Hospital County Encoded',
 'Facility Name Encoded',
 'Age Group Encoded',
 'Zip Code - 3 digits Encoded',
 'Gender Encoded',
 'Race Encoded',
 'Length of Stay Encoded',
 'Type of Admission Encoded',
 'Patient Disposition Encoded',
 'CCS Diagnosis Description Encoded',
 'CCS Procedure Description Encoded',
 'APR DRG Description Encoded',
 'APR MDC Description Encoded',
 'APR Severity of Illness Description Encoded',
 'APR Risk of Mortality Encoded',
 'APR Medical Surgical Description Encoded',
 'Source of Payment 1 Encoded',
 'Source of Payment 2 Encoded',
 'Abortion Edit Indicator Encoded',
 'Emergency Department Indicator Encoded']

y = 'Ethnicity Encoded'

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(modified_df[X], modified_df[y], test_size=0.2, random_state=42)

# Create and configure the SGD Classifier
sgd_classifier = SGDClassifier(loss='hinge', alpha=0.001, max_iter=1000, random_state=42)

# Train the classifier on the training data
sgd_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = sgd_classifier.predict(X_test)

# Evaluate the classifier's performance (e.g., accuracy)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.81

# %%
modified_df['Ethnicity'].unique()
# Out:
# array(['Not Span/Hispanic', 'Spanish/Hispanic', 'Unknown'], dtype=object)

# %% [markdown]
# Let's classify ethnicity while dropping 'Unknown'

# %%
modified_df = modified_df[modified_df['Ethnicity'] != 'Unknown']

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(modified_df[X], modified_df[y], test_size=0.2, random_state=42)

# Create and configure the SGD Classifier
sgd_classifier = SGDClassifier(loss='hinge', alpha=0.001, max_iter=1000, random_state=42)

# Train the classifier on the training data
sgd_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = sgd_classifier.predict(X_test)

# Evaluate the classifier's performance (e.g., accuracy)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.85

# %%
sgd_classifier.get_params()
# Out:
# {'alpha': 0.001,
#  'average': False,
#  'class_weight': None,
#  'early_stopping': False,
#  'epsilon': 0.1,
#  'eta0': 0.0,
#  'fit_intercept': True,
#  'l1_ratio': 0.15,
#  'learning_rate': 'optimal',
#  'loss': 'hinge',
#  'max_iter': 1000,
#  'n_iter_no_change': 5,
#  'n_jobs': None,
#  'penalty': 'l2',
#  'power_t': 0.5,
#  'random_state': 42,
#  'shuffle': True,
#  'tol': 0.001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Classification of Risk of Mortality
# The risk of mortality provides a medical classification to estimate the likelihood of in-hospital death for a patient.

# %%
X = [
 'Operating Certificate Number',
 'Facility ID',
 'Discharge Year',
 'CCS Diagnosis Code',
 'CCS Procedure Code',
 'APR DRG Code',
 'APR MDC Code',
 'APR Severity of Illness Code',
 'Attending Provider License Number',
 'Operating Provider License Number',
 'Birth Weight',
 'Total Charges',
 'Total Costs',
 'Health Service Area Encoded',
 'Hospital County Encoded',
 'Facility Name Encoded',
 'Age Group Encoded',
 'Zip Code - 3 digits Encoded',
 'Gender Encoded',
 'Race Encoded',
 'Ethnicity Encoded',
 'Length of Stay Encoded',
 'Type of Admission Encoded',
 'Patient Disposition Encoded',
 'CCS Diagnosis Description Encoded',
 'CCS Procedure Description Encoded',
 'APR DRG Description Encoded',
 'APR MDC Description Encoded',
 'APR Severity of Illness Description Encoded',
 'APR Medical Surgical Description Encoded',
 'Source of Payment 1 Encoded',
 'Source of Payment 2 Encoded',
 'Abortion Edit Indicator Encoded',
 'Emergency Department Indicator Encoded']

y = 'APR Risk of Mortality Encoded'

# %%
modified_df['APR Risk of Mortality'].unique()
# Out:
# array(['Minor', 'Moderate', 'Major', 'Extreme'], dtype=object)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(modified_df[X], modified_df[y], test_size=0.2, random_state=42)

# Create and configure the SGD Classifier
sgd_classifier = SGDClassifier(loss='hinge', alpha=0.001, max_iter=1000, random_state=42)

# Train the classifier on the training data
sgd_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = sgd_classifier.predict(X_test)

# Evaluate the classifier's performance (e.g., accuracy)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.60

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(modified_df[X], modified_df[y], test_size=0.25, random_state=42)

# Create and configure the RandomForest Classifier
rf_classifier = RandomForestClassifier(n_estimators = 100, n_jobs = -1) 

# Train the classifier on the training data
rf_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf_classifier.predict(X_test)

# Evaluate the classifier's performance (e.g., accuracy)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Hyper Parameter Tuning (Grid Search)

# %%
rf_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid_param = {
    'n_estimators': [200],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [False]
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(rf_classifier, grid_param, cv=5, scoring=None, n_jobs=8)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
print('----------------------RESULTS----------------------')
y_pred = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
print("Best Params:    ", best_params)
# Out:
# C:\Users\borad\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\borad\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# Grid Search giving errors due to lots(>1.5 Million) of data
# https://github.com/scikit-learn-contrib/hdbscan/issues/494

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(rf_classifier, grid_param, cv=5, scoring=None, n_jobs=8)
grid_search.fit(X_train.sample(frac=0.1), y_train.sample(frac=0.1))

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
print('----------------------RESULTS----------------------')
y_pred = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
print("Best Params:    ", best_params)
# Out:
# C:\Users\borad\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ----------------------RESULTS----------------------
# Accuracy: 0.81
# Best Params:     {'bootstrap': False, 'criterion': 'entropy', 'n_estimators': 200}
